# %% [markdown]
# <a href="https://colab.research.google.com/github/trideebai11/python_programming/blob/main/Day3_In_Class_Assignments_TrideebArandhara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ****THIS IS MY THIRD NOTEBOOK FOR PYTHON WORK**

# %% [markdown]
# #Python If...Else:

# %% [markdown]
# *Python Conditions and If statements

# %% [markdown]
# *We can have multiple statements inside an if block indented at the same level.

# %%
age = 20

if age >= 18:
  print("You are an adult")
  print("You can vote")
  print("You have full legal rights")
# Out:
# You are an adult
# You can vote
# You have full legal rights

# %% [markdown]
# *Boolean variables can be used directly in if statements without comparison operators.

# %%
is_logged_in = True

if is_logged_in:
  print("Welcome back!")
# Out:
# Welcome back!

# %% [markdown]
# #Python Elif Statement:

# %% [markdown]
# *The elif keyword is Python's way of saying "if the previous conditions were not true, then try this condition".

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b: #This indicates equality
  print("a and b are equal")
# Out:
# a and b are equal

# %%
#The program checks each condition in order. Since score is 75, it prints "Grade: C" (the first condition that evaluates to true).
score = 75

if score >= 90:
  print("Grade: A")
elif score >= 80:
  print("Grade: B")
elif score >= 70:
  print("Grade: C")
elif score >= 60:
  print("Grade: D")
# Out:
# Grade: C

# %% [markdown]
# *When you use elif, Python evaluates the conditions from top to bottom. As soon as it finds a condition that is true, it executes that block and skips all remaining conditions.
#
# *Even if multiple conditions are true, Python stops after executing the first matching block.

# %%
age = 25

if age < 13:
  print("You are a child")
elif age < 20:
  print("You are a teenager")
elif age < 65:
  print("You are an adult")
elif age >= 65:
  print("You are a senior")
# Out:
# You are an adult

# %% [markdown]
# *We use elif when we have multiple mutually exclusive conditions to check. This is more efficient than using multiple separate if statements because Python stops checking once it finds a true condition

# %%
day = 3

if day == 1:
  print("Monday")
elif day == 2:
  print("Tuesday")
elif day == 3:
  print("Wednesday")
elif day == 4:
  print("Thursday")
elif day == 5:
  print("Friday")
elif day == 6:
  print("Saturday")
elif day == 7:
  print("Sunday")
# Out:
# Wednesday

# %% [markdown]
# #Python Else Statement:

# %% [markdown]
# *The else statement is executed when the if condition and any elif conditions evaluate to False.

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# The else statement provides a default action when none of the previous conditions are true.

# %%
number = 7

if number % 2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# The number is odd

# %%
temperature = 22

if temperature > 30:
  print("It's hot outside!")
elif temperature > 20:
  print("It's warm outside")
elif temperature > 10:
  print("It's cool outside")
else:
  print("It's cold outside!")
# Out:
# It's warm outside

# %% [markdown]
# *The else statement acts as a fallback that executes when none of the preceding conditions are true. This makes it useful for error handling, validation, and providing default values.

# %%
username = "Trideeb"

if len(username) > 0:
  print(f"Welcome, {username}!")
else:
  print("Error: Username cannot be empty")
# Out:
# Welcome, Trideeb!

# %% [markdown]
# *Multiple Conditions on One Line

# %%
a = 330
b = 330
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# =

# %%
a = 33
b = 200
if not a > b:
  print("a is NOT greater than b")
# Out:
# a is NOT greater than b

# %% [markdown]
# *If statement to find the maximum of two numbers

# %%
x = 15
y = 20
max_value = x if x > y else y
print("Maximum value:", max_value)
# Out:
# Maximum value: 20

# %%
username = ""
display_name = username if username else "Guest"
print("Welcome,", display_name)
# Out:
# Welcome, Guest

# %% [markdown]
# #Python Logical Operators:

# %% [markdown]
# *Python evaluates "not" first, then "and", then "or".

# %%
age = 25
is_student = False
has_discount_code = True

if (age < 18 or age > 65) and not is_student or has_discount_code: #not (is_student) first = true, False and True= False, False or True= True
  print("Discount applies!")
# Out:
# Discount applies!

# %% [markdown]
# *We should use parentheses when we combine multiple logical operators, to make our intentions clear and control the order of evaluation.

# %%
temperature = 25
is_raining = False
is_weekend = True

if (temperature > 20 and not is_raining) or is_weekend: #True and True or True
  print("Great day for outdoor activities!")
# Out:
# Great day for outdoor activities!

# %%
username = "Trideeb"
password = "secret123"
is_verified = True

if username and password and is_verified:
  print("Login successful")
else:
  print("Login failed")
# Out:
# Login successful

# %% [markdown]
# #Nested If Statements:

# %% [markdown]
# *We can have if statements inside if statements. The inner if statement only runs if the outer condition is true.

# %%
age = 25
has_license = True

if age >= 18:
  if has_license:
    print("You can drive")
  else:
    print("You need a license")
else:
  print("You are too young to drive")
# Out:
# You can drive

# %% [markdown]
# *Multiple Levels of Nesting

# %%
score = 85
attendance = 90
submitted = True

if score >= 60:
  if attendance >= 80:
    if submitted:
      print("Pass with good standing")
    else:
      print("Pass but missing assignment")
  else:
    print("Pass but low attendance")
else:
  print("Fail")
# Out:
# Pass with good standing

# %% [markdown]
# *Sometimes nested if statements can be simplified using logical operators like "and"

# %%
temperature = 25
is_sunny = True

if temperature > 20:
  if is_sunny:
    print("Perfect beach weather!")
# Out:
# Perfect beach weather!

# %%
temperature = 25
is_sunny = True

if temperature > 20 and is_sunny: #and operator used to simplify statement
  print("Perfect beach weather!")
# Out:
# Perfect beach weather!

# %%
#Login validation with nested checks:

username = "Trideeb"
password = "python123"
is_active = True

if username:
  if password:
    if is_active:
      print("Login successful")
    else:
      print("Account is not active")
  else:
    print("Password required")
else:
  print("Username required")
# Out:
# Login successful

# %%
score = 92
extra_credit = 5

if score >= 90:
  if extra_credit > 0:
    print("A+ grade")
  else:
    print("A grade")
elif score >= 80:
  print("B grade")
else:
  print("C grade or below")
# Out:
# A+ grade

# %% [markdown]
# *Python Pass Statement

# %%
#The pass statement is a null operation - nothing happens when it executes. It serves as a placeholder.

age = 19
if age < 18:
  pass # TODO: Add underage logic later
else:
  print("Access granted")
# Out:
# Access granted

# %%
score = 85

if score > 90:
  pass # This is excellent
print("Score processed")
# Out:
# Score processed

# %% [markdown]
# *Pass with Multiple Conditions

# %%
value = 50

if value < 0:
  print("Negative value")
elif value == 0:
  pass # Zero case - no action needed
else:
  print("Positive value")
# Out:
# Positive value

# %% [markdown]
# #Python Match:

# %% [markdown]
# *Instead of writing many if..else statements, we can use the match statement.
#
# The "match" statement selects one of many code blocks to be executed.

# %%
day = 4
match day:
  case 1:
    print("Monday")
  case 2:
    print("Tuesday")
  case 3:
    print("Wednesday")
  case 4:
    print("Thursday")
  case 5:
    print("Friday")
  case 6:
    print("Saturday")
  case 7:
    print("Sunday")
# Out:
# Thursday

# %% [markdown]
# *We can use the underscore character _ as the last case value if we want a code block to execute when there are not other matches

# %%
day = 4
match day:
  case 6:
    print("Today is Saturday")
  case 7:
    print("Today is Sunday")
  case _:
    print("Looking forward to the Weekend")
# Out:
# Looking forward to the Weekend

# %% [markdown]
# *Use the pipe character | as an or operator in the case evaluation to check for more than one value match in one case

# %%
day = 4
match day:
  case 1 | 2 | 3 | 4 | 5:
    print("Today is a weekday")
  case 6 | 7:
    print("I love weekends!")
# Out:
# Today is a weekday

# %% [markdown]
# You can add if statements in the case evaluation as an extra condition-check

# %%
month = 5
day = 4
match day:
  case 1 | 2 | 3 | 4 | 5 if month == 4:
    print("A weekday in April")
  case 1 | 2 | 3 | 4 | 5 if month == 5:
    print("A weekday in May")
  case _:
    print("No match")
# Out:
# A weekday in May

# %% [markdown]
# #Python While Loops:

# %% [markdown]
# *With the while loop we can execute a set of statements as long as a condition is true

# %%
i = 1
while i < 6:
  print(i)
  i += 1 #We should remember to increment i, or else the loop will continue forever
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# *With the break statement we can stop the loop even if the while condition is true

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# *With the continue statement we can stop the current iteration, and continue with the next:

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue #skip number 3
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# *With the else statement we can run a block of code once when the condition no longer is true:

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %% [markdown]
# #Python For Loops

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
  if x == "banana":
    break
# Out:
# apple
# banana

# %% [markdown]
# *Exit the loop when x is "banana", but this time the break comes before the print:

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple

# %% [markdown]
# *With the continue statement we can stop the current iteration of the loop, and continue with the next:

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
# Out:
# apple
# cherry

# %% [markdown]
# *The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and ends at a specified number.

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# *The range() function defaults to increment the sequence by 1, however it is possible to specify the increment value by adding a third parameter

# %%
for x in range(2, 30, 3): #jumps 3 places
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2

# %% [markdown]
# *Nested Loop is a loop inside a loop. The "inner loop" executes one time for each iteration of the "outer loop":

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %% [markdown]
# *Pass statement: for loops cannot be empty, but if for some reason we have a for loop with no content, we put in the pass statement to avoid getting an error.

# %%
for x in [0, 1, 2]:
  pass
