# %% [markdown]
# <a href="https://colab.research.google.com/github/trideebai11/python_programming/blob/main/Day2_In_Class_Assignments_TrideebArandhara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ****THIS IS MY SECOND NOTEBOOK FOR PYTHON WORK**

# %% [markdown]
# Python Data Types: str*, int*, float*, complex*, list, tuple, range, dict*, set*, frozenset, bool*, bytes, bytearray, memoryview, NoneType
#
# (Starred the types which are most commonly used)

# %%
x = "Hello World"
print(x)
print(type(x)) #display the data type of x
# Out:
# Hello World
# <class 'str'>

# %%
x = 0+1j #0 is real part and 1 is imaginary part multiplied by j. Here j which means √-1
print(x)
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %% [markdown]
# *Double parentheses are used when we are pass a tuple into the set() function.

# %%
x = set(("apple", "banana", "cherry"))
print(x)
print(type(x))
# Out:
# {'banana', 'cherry', 'apple'}
# <class 'set'>

# %%
x = {1, 2, 3}
x.add(4) #attribute add works in case of set
print(s)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# *We can add or remove items from a set but a frozenset cannot be changed

# %%
x = frozenset(("apple", "banana", "cherry"))
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'cherry', 'apple'})
# <class 'frozenset'>

# %%
fs = frozenset([1, 2, 3])
#fs.add(4) #frozenset has no attribute "add" because frozenset cannot be modified
print(fs)
# Out:
# frozenset({1, 2, 3})

# %%
a = {1, 2, 3} #mutable set with elements {1, 2, 3}
b = frozenset([3, 4, 5]) #immutable frozenset with elements {3, 4, 5}
print(a.union(b))
print(a.intersection(b))
# Out:
# {1, 2, 3, 4, 5}
# {3}

# %% [markdown]
# *In binary, each zero byte looks like \x00.
#
# Each \x00 means one byte with value 0

# %%
x = bytes(5)
print(x)
print(type(x))
# Out:
# b'\x00\x00\x00\x00\x00'
# <class 'bytes'>

# %%
x = bytearray(5)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %% [markdown]
# *In the memoryview type, the memory address will vary each time

# %%
x = memoryview(bytes(5))
print(x)
print(type(x))
# Out:
# ...
# <class 'memoryview'>

# %% [markdown]
# *Python Numbers

# %%
x = 1    # int
y = 2.8  # float
z = 1j   # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# *Int or integer is a whole number. It may be positive or negative without decimals of unlimited length.

# %%
x = 1
y = 35656222554887711
z = -3255522
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# *Float or floating point number is a number which may be positive or negative, containing one or more decimals.

# %%
x = 1.10
y = 1.0
z = -35.59 #floating point number
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# *Float can also be scientific numbers with an "e" which indicates the power of 10.

# %%
x = 35e3
y = 12E4
z = -87.7e100
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# *Complex numbers are written with a "j" as the imaginary part

# %%
x = 3+5j
y = 5j
z = -5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %% [markdown]
# *Convert from one type to another

# %%
x = 1
y = 2.8
z = 1j
a = float(x) #convert from int to float
b = int(y) #convert from float to int
c = complex(x) #convert from int to complex
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %% [markdown]
# *The function randrange is useful in pythons random module.
#
# The module random is imported which is used to print a random integer between 1 and 9 (inclusive of 1, exclusive of 10).

# %%
import random

print(random.randrange(1, 10)) #
# Out:
# 5

# %% [markdown]
# Python Casting:

# %%
#integers
x = int(1)
y = int(2.8)
z = int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
#floats
x = float(1)
y = float(2.8)
z = float("3")
w = float("4.2")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %%
#strings
x = str("s1")
y = str(2)
z = str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %% [markdown]
# Python Strings:

# %% [markdown]
# *Strings in python are surrounded by either single quotation marks, or double quotation marks.

# %%
a = "Hello, how are you?"
print(a)
# Out:
# Hello, how are you?

# %% [markdown]
# *Multiline Strings

# %%
#Assigning a multiline string to a variable by using three double quotes
a = """Work hard and dream with purpose,
grow with patience and with grace,
let each moment teach you something,
and find joy in every place.""" #this can be used as a comment also
print(a)
# Out:
# Work hard and dream with purpose,
# grow with patience and with grace,
# let each moment teach you something,
# and find joy in every place.

# %%
#Assigning a multiline string to a variable by using three single quotes
a = '''Work hard and dream with purpose,
grow with patience and with grace,
let each moment teach you something,
and find joy in every place.'''
print(a)
# Out:
# Work hard and dream with purpose,
# grow with patience and with grace,
# let each moment teach you something,
# and find joy in every place.

# %% [markdown]
# *Strings are Arrays

# %%
a = "Hello, World!"
print(a[1]) #a[1] will give the character at position 1
# Out:
# e

# %% [markdown]
# *Looping Through a String

# %%
for x in "banana": #use with spaces
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# *String Length

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %% [markdown]
# *Check String

# %% [markdown]
# *To check if a certain phrase or character is present in a string, we can use the keyword in.

# %%
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %% [markdown]
# *Will print only if "free" is present
#
# *free will be taken from the word freedom also

# %%
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %% [markdown]
# *To check if a certain phrase or character is NOT present in a string, we can use the keyword not in.

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "expensive" not in txt: #also mean if NOT TRUE print
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %% [markdown]
# *Slicing Strings

# %% [markdown]
# *We specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [markdown]
# *Slice From the Start

# %%
b = "Hello, World!"
print(b[:5]) #Get the characters from the start to position 5 (not included)
# Out:
# Hello

# %% [markdown]
# *Slice To the End

# %%
b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %% [markdown]
# *Negative Indexing

# %%
b = "Hello, World!"
print(b[-5:-2]) #Here H is -13 and ! is -1
# Out:
# orl

# %% [markdown]
# *Python - Modify Strings

# %%
#Upper case
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
#Lower case
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %% [markdown]
# *The strip() method removes any whitespace from the beginning or the end

# %%
a = " Hello, World! " #whitespaces before and after
print(a.strip())
# Out:
# Hello, World!

# %% [markdown]
# *The replace() method replaces a string with another string

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %% [markdown]
# *The split() method returns a list where the text between the specified separator becomes the list items

# %%
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %% [markdown]
# *String Concatenation

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %% [markdown]
# *String Format

# %% [markdown]
# *We can combine strings and numbers by using f-strings or the format() method

# %%
age = 36
txt = f"My name is John, I am {age}"
print(txt)
# Out:
# My name is John, I am 36

# %% [markdown]
# *Placeholders and Modifiers
#
# *A placeholder can contain variables, operations, functions, and modifiers to format the value.

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %% [markdown]
# *A placeholder can include a modifier to format the value.
#
# A modifier is included by adding a colon : followed by a legal formatting type, like .2f which means fixed point number with 2 decimals:

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %% [markdown]
# *A placeholder can contain Python code, like math operations:

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %% [markdown]
# *Escape Character
#
# *An escape character is a backslash \ followed by the character we want to insert.

# %%
txt = "We are the so-called \"Vikings from the north."
print(txt)
txt1 = "We are the so-called \"Vikings\' from the north."
print(txt1)
# Out:
# We are the so-called "Vikings from the north.
# We are the so-called "Vikings' from the north.

# %% [markdown]
# *Escape characters used in python: \'- Single Quote, \\- Backslash*, \n- New Line*, \r- Carriage Return, \t- Tab*, \b- Backspace, \f- Form Feed, \ooo- Octal value, \xhh- Hex value

# %%
txt = "Hello\rWorld!"
print(txt)
# Out:
# World!

# %% [markdown]
# *String Methods:

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %% [markdown]
# Python Booleans:

# %% [markdown]
# *Evaluating a string and a number

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %% [markdown]
# *Evaluating two variables

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
bool("abc") #Any non-empty string is considered True
bool(123) #Any non-zero number positive or negative is True
bool(["apple", "cherry", "banana"]) #Non empty list is True
# Out:
# True

# %% [markdown]
# *There are not many values that evaluate to False, except empty values, such as (), [], {}, "", the number 0, and the value None.

# %%
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# *An object will evaluate to False if it comes from a class whose __len__() method returns 0 or False.

# %%
class myclass():
  def __len__(self):
    return 0
myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
def myFunction() :
  return True
if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# YES!

# %%
#Check if an object is an integer or not
x = 200
print(isinstance(x, int))
# Out:
# True

# %% [markdown]
# *Python Operators:

# %%
sum1 = 100 + 50
sum2 = sum1 + 250
sum3 = sum2 + sum2
print(sum1)
print(sum2)
print(sum3)
# Out:
# 150
# 400
# 800

# %% [markdown]
# *Arithmetic Operators

# %%
x = 15
y = 4
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y) #% represents Modulus or remainder
print(x ** y) #** represents exponentiation i.e. 15^4
print(x // y) #// represents floor division which rounds the result down to the nearest whole number
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3

# %% [markdown]
# *Assignment Operators:
#
# The := operator is known as the "walrus operator". It assigns values to variables as part of a larger expression.

# %%
numbers = [1, 2, 3, 4, 5]
count = len(numbers)
if count > 3:
    print(f"List has {count} elements")

if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements
# List has 5 elements

# %% [markdown]
# *Comparison Operators return True or False based on the comparison

# %%
x = 5
y = 3
print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# *Chaining Comparison Operators

# %%
x = 5
print(1 < x < 10)
print(1 < x and x < 10)
# Out:
# True
# True

# %% [markdown]
# *Logical Operators

# %%
x = 5
print(x < 5 or x > 10)
# Out:
# False

# %%
x = 5
print(x > 3 and x < 10)
# Returns True because 5 is greater than 3 AND 5 is less than 10
# Out:
# True

# %%
x = 5
print(x > 3 or x < 4)
# Returns True because one of the conditions are true (5 is greater than 3, but 5 is not less than 4)
# Out:
# True

# %%
x = 5
print(not(x > 3 and x < 10)) #Reverse the result with not
#Returns False because not is used to reverse the result
# Out:
# False

# %% [markdown]
# *Identity Operators

# %%
x = ["apple", "banana"]
y = ["apple", "banana"] #y is a new list object with the same content, but have different memory location.
z = x
print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %% [markdown]
# *Membership Operators

# %%
fruits = ["apple", "banana", "cherry"]
print("banana" in fruits) #Will give True output as it is present
# Out:
# True

# %%
x = [1, 2, 3]
y = [1, 2, 3]
print(x == y) #Elements inside x and y are same
print(x is y)
# Out:
# True
# False

# %%
text = "Hello World"
print("H" in text)
print("hello" in text)
print("z" not in text)
# Out:
# True
# False
# True

# %% [markdown]
# Bitwise Operators: & AND, | OR, ^ XOR, ~ NOT, << Zero fill left shift, >> Signed right shift

# %% [markdown]
# *The & operator compares each bit and set it to 1 if both are 1, otherwise it is set to 0

# %%
# 6 = 0110
# 3 = 0011
# 2 = 0010

print(6 & 3)
# Out:
# 2

# %% [markdown]
# *The | operator compares each bit and set it to 1 if one or both is 1, otherwise it is set to 0

# %%
# 6 = 0110
# 3 = 0011
# 7 = 0111

print(6 | 3)
# Out:
# 7

# %% [markdown]
# *The ^ operator compares each bit and set it to 1 if only one is 1, otherwise it is set to 0

# %%
# 6 = 0110
# 3 = 0011
# 5 = 0101

print(6 ^ 3)
# Out:
# 5

# %% [markdown]
# *The ~ operator inverts each bit (0 becomes 1 and 1 becomes 0)

# %%
print(~3)

#Inverted 3 becomes -4:
#3 = 0000000000000011
#-4 = 1111111111111100
# Out:
# -4

# %% [markdown]
# *The << operator inserts the specified number of 0's (in this case 2) from the right and let the same amount of leftmost bits fall off

# %%
print(3 << 2)

#Push 00 in from the left:
#3 = 0000000000000011
#becomes
#12 = 0000000000001100
# Out:
# 12

# %% [markdown]
# *The >> operator moves each bit the specified number of times to the right. Empty holes at the left are filled with 0's.

# %%
print(8 >> 2)

#Each bit moved 2 times to the right, so 8 becomes 2:
#8 = 0000000000001000
#becomes
#2 = 0000000000000010
# Out:
# 2

# %% [markdown]
# *Operator Precedence
#
# Parentheses has the highest precedence, meaning that expressions inside parentheses must be evaluated first

# %%
 print((6 + 3) - (6 + 3))
# Out:
# 0

# %% [markdown]
# Multiplication * has higher precedence than addition +, and therefore multiplications are evaluated before additions

# %%
print(100 + 5 * 3)
# Out:
# 115

# %% [markdown]
# Addition + and subtraction - has the same precedence, and therefore we evaluate the expression from left to right

# %%
print(5 + 4 - 7 + 3)
# Out:
# 5

# %% [markdown]
# Python Lists:

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"] #Since lists are indexed, lists can have items with the same value

print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
mylist = ["apple", "banana", "cherry"]

print(type(mylist))
# Out:
# <class 'list'>

# %%
thislist = list(("apple", "banana", "cherry")) #note the double round-brackets
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# *Python Collections (Arrays)
#
# *List is a collection which is ordered and changeable. Allows duplicate members. Easy indexation
#
# *Tuple is a collection which is ordered and unchangeable. Allows duplicate members.Tuples are more to write once and read many times
#
# **Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members. Deduplication
#
# *Dictionary is a collection which is ordered and changeable. No duplicate members. JSON is a nested dictionary

# %%
#Change Item Value
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
#Change a Range of Item Values
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %%
#Change the second value by replacing it with two new values
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
#If we insert less items than we replace, then the new items will be inserted where we have specified and the remaining items will move accordingly
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
#Insert Items
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %% [markdown]
# Append Items

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %% [markdown]
# *The extend() method does not have to append lists, we can add any iterable object (tuples, sets, dictionaries etc)

# %%
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
mylist = ['apple', 'banana', 'cherry']
mylist.insert(0, 'orange') #orange takes 0 and apple shifts to 1
print(mylist[1])
# Out:
# apple

# %% [markdown]
# *The remove() method removes the specified item

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# *If there are more than one item with the specified value, the remove() method removes the first occurrence

# %%
thislist = ["apple", "banana", "cherry", "banana", "kiwi"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry', 'banana', 'kiwi']

# %% [markdown]
# *The pop() method removes the specified index

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# *If you do not specify the index, the pop() method removes the last item

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %% [markdown]
# *The del keyword removes the specified index

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# *The del keyword can also delete the list completely

# %%
thislist = ["apple", "banana", "cherry"]
del thislist
print(thislist) #this will cause an error because we have succsesfully deleted "thislist"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2769185519.py in <cell line: 0>()
#       2 thislist = ["apple", "banana", "cherry"]
#       3 del thislist
# ----> 4 print(thislist) #this will cause an error because you have succsesfully deleted "thislist".
#
# NameError: name 'thislist' is not defined

# %% [markdown]
# *The clear() method empties the list.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %% [markdown]
# *Loop Through a List

# %%
#We can loop through the list items by using a for loop

thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# *Loop Through the Index Numbers

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)): #this list 3 #iterable created in the example is [0, 1, 2]
  print(thislist[i])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# *Using a While Loop

# %%
thislist = ["apple", "banana", "cherry"]
i = 0 #initialization i=0
while i < len(thislist): #length is 3
  print(thislist[i]) #i=0
  i = i + 1 #0+1
# Out:
# apple
# banana
# cherry

# %% [markdown]
# *Looping Using List Comprehension

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %% [markdown]
# List Comprehension
#
# *List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# *With list comprehension we can do all that with only one line of code

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
# newlist = [expression for item in iterable if condition == True]
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

#newlist = [x for x in fruits if x != "apple"]
#newlist = ['hello' for x in fruits]
newlist = [x if x != "banana" else "orange" for x in fruits]  #x not equal to banana

print(newlist)
# Out:
# ['apple', 'orange', 'cherry', 'kiwi', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x.upper() for x in fruits]

print(newlist)
# Out:
# ['APPLE', 'BANANA', 'CHERRY', 'KIWI', 'MANGO']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = ['hello' for x in fruits] #Replaces all with the word hello

print(newlist)
# Out:
# ['hello', 'hello', 'hello', 'hello', 'hello']

# %% [markdown]
# *Sort List Alphanumerically

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = True)
print(thislist)
# Out:
# [100, 82, 65, 50, 23]

# %% [markdown]
# *We can customize your own function by using the keyword argument key = function

# %%
def myfunc(n):
  return abs(n - 50) #Sort the list based on how close the number is to 50, 50 51 52 53....
#abs() gives the absolute value i.e. ignores negative sign

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 23, 82, 100]

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 35, 65, 82, 23] #both 35 and 65 are 15 numbers apart from 50
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 35, 65, 23, 82, 100]

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 35, 82, 23]
thislist.sort(key = myfunc)
print(thislist)
# Out:
# [50, 65, 35, 23, 82, 100]

# %% [markdown]
# *The sort() method is case sensitive, resulting in all capital letters being sorted before lower case letters

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key = str.lower)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %% [markdown]
# Copy a List
#
# *We cannot copy a list simply by typing list2 = list1, because list2 will only be a reference to list1, and changes made in list1 will automatically also be made in list2

# %%
#Use the copy() method
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# *Another way to make a copy is to use the built-in method list()

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# *We can also make a copy of a list by using the : (slice) operator

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
thislist = ["apple", "banana", "cherry", "orange"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
thislist = ["apple", "banana", "cherry", "orange"]
print(thislist)
newlist=thislist
print(newlist)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# *Join Two Lists using + operator

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# *Another way to join two lists is by appending all the items from list2 into list1, one by one

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# *The purpose of extend() method is to add elements from one list to another list

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# Tuple:
#
# *Tuples are used to store multiple items in a single variable.
#
# *A tuple is a collection which is ordered and unchangeable.
#
# *Tuples are written with round brackets.
#
# *Tuple items are ordered, unchangeable, and allow duplicate values.
#
# *Tuple items are indexed, the first item has index [0], the second item has index [1] etc.

# %%
#Create Tuple With One Item
thistuple = ("apple",) #One item tuple as there is a comma after the first item apple)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple") #without the comma it is a string
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
#We can use the tuple() constructor to make a tuple.

thistuple = tuple(("apple", "banana", "cherry"))
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# Change Tuple Values:
#
# *Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",) #it will be considered a tuple only if the , is added after the item
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('banana', 'cherry')

# %% [markdown]
# Unpacking a Tuple

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits #asterisk needs to be added before item name

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits #green-first item, red-last item, *tropic- everything else in the middle

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %% [markdown]
# Set:
#
# *Sets are used to store multiple items in a single variable.
#
# *Set items are unchangeable, but you can remove items and add new items, however it cannot have two items with the same value
#
# *Sets are written with curly brackets.
#
# *Set items are unordered, unchangeable, and do not allow duplicate values.

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# *The values True and 1 are considered the same value in sets, and are treated as duplicates

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}
print(thisset)
# Out:
# {True, 2, 'banana', 'cherry', 'apple'}

# %% [markdown]
# *The values False and 0 are considered the same value in sets, and are treated as duplicates

# %%
thisset = {"apple", "banana", "cherry", False, True, 0}

print(thisset)
# Out:
# {False, True, 'banana', 'cherry', 'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

print(set1)
print(set2)
print(set3)
# Out:
# {'cherry', 'banana', 'apple'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
myset = {"apple", "banana", "cherry"}
print(type(myset))
# Out:
# <class 'set'>

# %% [markdown]
# *The update() method is used to add items from another set into the current set

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}
thisset.update(tropical)

print(thisset)
# Out:
# {'pineapple', 'mango', 'papaya', 'cherry', 'banana', 'apple'}

# %% [markdown]
# *The update() method does not have to be a set, it can be any iterable object (tuples, lists, dictionaries etc.)

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]
thisset.update(mylist)

print(thisset)
# Out:
# {'kiwi', 'apple', 'cherry', 'banana', 'orange'}

# %% [markdown]
# *The pop() method is used to remove an item, but this method will remove a random item, so we cannot be sure what item that gets removed

# %%
thisset = {"apple", "banana", "cherry"}
x = thisset.pop()
print(x) #removed item
print(thisset) #the set after removal
# Out:
# cherry
# {'banana', 'apple'}

# %% [markdown]
# Join Sets:
#
# *There are several ways to join two or more sets in Python.
#
# *The union() and update() methods joins all items from both sets.
#
# *The intersection() method keeps ONLY the duplicates.
#
# *The difference() method keeps the items from the first set that are not in the other set(s).
#
# *The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {'a', 1, 2, 3, 'b', 'c'}

# %% [markdown]
# *The union() method is used to join multiple sets

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {1, 2, 3, 'John', 'bananas', 'a', 'c', 'apple', 'b', 'Elena', 'cherry'}

# %% [markdown]
# *We can use the | operator instead of the union() method, and we will get the same result.
#
# *When using the | operator, separate the sets with more | operators

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1 | set2 | set3 |set4
print(myset)
# Out:
# {1, 2, 3, 'John', 'bananas', 'a', 'c', 'apple', 'b', 'Elena', 'cherry'}

# %% [markdown]
# *The update() method inserts all items from one set into another.
#
# *The update() changes the original set, and does not return a new set.

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {'a', 1, 2, 3, 'b', 'c'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2) #common element
print(set3)
# Out:
# {'apple'}

# %% [markdown]
# *The intersection_update() method will keep ONLY the duplicates, but it will change the original set instead of returning a new set.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}

set3 = set1.intersection(set2) #Join sets that contains the values True, False, 1, and 0, and see what is considered as duplicates

print(set3)
# Out:
# {False, 1, 'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2) #Keep all items from set1 that are not in set2

print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2 #Used to join two sets
print(set3)
# Out:
# {'cherry', 'banana'}

# %% [markdown]
# *The difference_update() method is used to keep the items that are not present in both sets

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'banana', 'cherry'}

# %% [markdown]
# *The symmetric_difference returns a new set containing all elements that are in either of the sets,but not in both.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)
print(set3)
# Out:
# {'banana', 'cherry', 'google', 'microsoft'}

# %% [markdown]
# *The ^ operator can be used instead of the symmetric_difference() method which will get the same result

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'banana', 'cherry', 'google', 'microsoft'}

# %% [markdown]
# *The symmetric_difference_update() is used to keep the items that are not present in both sets

# %%
set1 = {"apple", "banana" , "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)
print(set1)
# Out:
# {'google', 'microsoft', 'cherry', 'banana'}

# %% [markdown]
# Python frozenset
#
# *frozenset is an immutable version of a set.
#
# *Like sets, it contains unique, unordered, unchangeable elements.
#
# *Unlike sets, elements cannot be added or removed from a frozenset.

# %%
x = frozenset({"apple", "banana", "cherry"})

print(x)
# Out:
# frozenset({'cherry', 'banana', 'apple'})

# %% [markdown]
# Dictionary:
#
# *Dictionaries are used to store data values in key:value pairs.
#
# *A dictionary is a collection which is ordered, changeable and do not allow duplicates.
#
# *Dictionaries are written with curly brackets, and have keys and values:

# %%
#Duplicate values will overwrite existing values:
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# *We can access the items of a dictionary by referring to its key name, inside square brackets.
#
# *The keys() method returns a list of all the keys in the dictionary.

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.keys()
print(x) #before the change

car["color"] = "white"
print(x) #after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %% [markdown]
# *The items() method returns each item in a dictionary, as tuples in a list.

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.items()
print(x) #before the change

car["year"] = 2020
print(x)
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2020)])

# %% [markdown]
# *The values() method returns a list of all the values in the dictionary.

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()
print(x) #before the change

car["year"] = 2020
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 2020])

# %% [markdown]
# *The items() method returns each item in a dictionary, as tuples in a list

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.items()
print(x) #before the change

car["color"] = "red"
print(x)
# Out:
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964), ('color', 'red')])

# %% [markdown]
# *The pop() method removes the item with the specified key name:

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# *The popitem() method removes the last inserted item

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict:
  print(x)
# Out:
# brand
# model
# year

# %%
thisdict =	{
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict:
  print(thisdict[x]) #Gives output of the values of x
# Out:
# Ford
# Mustang
# 1964

# %% [markdown]
# *Nested Dictionaries:

# %%
myfamily = {
  "child1" : {
    "name" : "Satyam",
    "year" : 2004
  },
  "child2" : {
    "name" : "Shivam",
    "year" : 2007
  },
  "child3" : {
    "name" : "Sundaram",
    "year" : 2011
  }
}

print(myfamily)
# Out:
# {'child1': {'name': 'Satyam', 'year': 2004}, 'child2': {'name': 'Shivam', 'year': 2007}, 'child3': {'name': 'Sundaram', 'year': 2011}}

# %% [markdown]
# *Loop Through Nested Dictionaries:
#
# *Here we are looping over the keys

# %%
myfamily = {
  "child1" : {
    "name" : "Satyam",
    "year" : 2004
  },
  "child2" : {
    "name" : "Shivam",
    "year" : 2007
  },
  "child3" : {
    "name" : "Sundaram",
    "year" : 2011
  }
}

for x, obj in myfamily.items():
    print(x)

    for y in obj:
        print(y + ':', obj[y])
# Out:
# child1
# name: Satyam
# year: 2004
# child2
# name: Shivam
# year: 2007
# child3
# name: Sundaram
# year: 2011
